# %%
import PyPDF2

def read_pdf_text(pdf_path):
    text = ""
    # Open the PDF file
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        # Iterate through all the pages
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text()  # Append page text to the main text string
    return text


# Example usage
pdf_path = "assignment_materials/Earning Call Transcript - One97 (Paytm).pdf"
pdf_text = read_pdf_text(pdf_path)
print(pdf_text)  # This will print all the text from the PDF
# Out:
#
#
#
#
#
#  Corporate Office - One Skymark, Tower -D, Pl ot No. H-10B, Sector -98, Noida -201304
# T: +91120 4770770   F: +91120 4770771 CIN: L72200DL2000PLC108985
# Registered Office -  136, First Floor, Devika Tower, Nehru Place, New Delhi -110019  One 97 Communications Limited
# compliance.officer@paytm.com
# www.paytm.com
#  October 29 , 2024
#
# BSE Limited
# Department of Corporate Services
# Phiroze Jeejeebhoy Towers,
# Dalal Street, Fort,
# Mumbai - 400 001
#
# Scrip Code: 543396   National Stock Exchange of India Limited
# The Listing Department
# Exchange Plaza ,
# Bandra Kurla Complex,
# Mumbai - 400 051
#
# Symbol: PAYTM
#
# Sub. :  Disclosure under Regulation 30 of the SEBI (Listing Obligations and Disclosure Requirements)
# Regulations, 2015 -  Transcript  of the earnings conference call  conducted on October  22, 2024
#
# Dear Sir / Ma’ am,
#
# Pursuant to Regulation 30 of the SEBI (Listing Obligations and Disclosure Requirements) Regulations,
# ...

# %%
import google.generativeai as genai
PROMPT ='''
Given the following transcript of a company call, please generate a JSON object summarizing the key points in the specified categories. The JSON should be structured exactly as follows and contain  summaries for each section:
{
  "company_name": "COMPANY NAME HERE",
  "financial_performance": "SHORT SUMMARY OF FINANCIAL PERFORMANCE HERE",
  "market_dynamics": "SHORT SUMMARY OF MARKET DYNAMICS HERE",
  "expansion_plans": "SHORT SUMMARY OF EXPANSION PLANS HERE",
  "environmental_risks": "SHORT SUMMARY OF ENVIRONMENTAL RISKS HERE",
  "regulatory_or_policy_changes": "SHORT SUMMARY OF REGULATORY OR POLICY CHANGES HERE"
}


Summary Categories:

Financial Performance: Summarize key financial metrics or statements about the company’s recent performance.
Market Dynamics: Summarize any commentary on market trends, demand shifts, competition, etc.
Expansion Plans: Summarize any information on the company's plans for growth or expansion.
Environmental Risks: Summarize references to environmental issues, sustainability, or ESG concerns.
Regulatory or Policy Changes: Summarize any information on recent or upcoming regulatory or policy changes affecting the company.

Please output only the JSON and no additional text.

Company Call Transcript:


'''

genai.configure(api_key="AIzaSyBcoTVmbn6XpziRf4DJIWj9a4sz-RqAgzU")
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content(PROMPT + pdf_text)
print(response.text)
# Out:
# {
#   "company_name": "One 97 Communications Limited (Paytm)",
#   "financial_performance": "Paytm reported strong financial results for the quarter and half year ending September 30, 2024. The company's net payment margin improved due to better monetization of merchants and control over payment gateway costs. Paytm also achieved a significant reduction in its cost base, with a focus on optimizing employee and software expenses. The company's contribution margin increased back to near 55% without UPI incentives.",
#   "market_dynamics": "Paytm highlighted the growing market practice of DLG (Direct Loan Guarantee) models in the lending industry. The company noted increased demand for merchant loans and saw an opportunity to expand its personal loans business by adding new lending partners.",
# ...

# %%
def call_model_api(prompt):
    genai.configure(api_key="AIzaSyBcoTVmbn6XpziRf4DJIWj9a4sz-RqAgzU")
    model = genai.GenerativeModel("gemini-1.5-flash")
    response = model.generate_content(prompt)
    return response.text

# %%
def generate_summary(transcript, category, details):
    prompt = f"""
    Given the following transcript, provide a concise summary specifically focused on {category}. The summary should contain:
    - {details}
    
    If there is no information related to {category} in the transcript, return only "NA".

    Only output the summary text or "NA" without any additional formatting.
    
    Transcript: "{transcript}"
    """
  
    response = call_model_api(prompt)
    return response.strip() 

def summarize_transcript(transcript):
    categories = {
        "Financial Performance": "key financial metrics or statements about the company’s recent performance",
        "Market Dynamics": "any commentary on market trends, demand shifts, competition, etc.",
        "Expansion Plans": "information on the company’s plans for growth or expansion",
        "Environmental Risks": "references to environmental issues, sustainability, or ESG concerns",
        "Regulatory or Policy Changes": "information on recent or upcoming regulatory or policy changes affecting the company"
    }
    summary_json = {}
    

    for category, details in categories.items():
        try:
            summary_json[category.lower().replace(" ", "_")] = generate_summary(transcript, category, details)
        except Exception as e:
            summary_json[category.lower().replace(" ", "_")] = "Error in generating summary"
      


    return {
        "company_name": "COMPANY NAME HERE",  
        **summary_json
    }

# %%
transcript = pdf_text
summary = summarize_transcript(transcript)
print(summary)
# Out:
# {'company_name': 'COMPANY NAME HERE', 'financial_performance': 'The company reported a significant improvement in net payment margin, driven by better monetization of merchants and control over payment gateway costs. This is expected to be the new run rate for coming quarters. The company is also focusing on increased monetization of devices, both through subscription revenues and redeployment of refurbished devices. The company has adopted a DLG (Discount on Loan Given) model for merchant loans, which has been fully expensed in the current quarter. The company expects to see higher collection revenues over the life of the loan under this model, while the overall takerate, net of DLG cost, is expected to be north of 5%. The company is open to extending the DLG model to other lending partners. The company has significantly reduced its cost base this quarter, and believes this to be the new base with potential for further reduction in the near term. The company expects its financial se
# ...

# %%
import requests
import json

# Define the API URL
url = "https://rishitchugh.pythonanywhere.com/earnings_transcript_summary"

# Sample valid input data
valid_data = {
    "company_name": "Reliance Industries",
    "transcript_text": pdf_text
}

# Sample invalid inputs for testing
missing_fields_data = {  # Missing "transcript_text"
    "company_name": "Reliance Industries"
}

empty_transcript_data = {
    "company_name": "Reliance Industries",
    "transcript_text": ""
}

too_long_transcript_data = {
    "company_name": "Reliance Industries",
    "transcript_text": "word " * 20001  # Exceeds 20,000 words
}

# Function to test API with different input cases
def test_api(data, description):
    print(f"Testing: {description}")
    response = requests.post(url, json=data)
    print("Status Code:", response.status_code)
    print("Response JSON:", response.json())
    print("-" * 50)

# Run tests
test_api(valid_data, "Valid input")                      # Expected: 200 OK with summary JSON
test_api(missing_fields_data, "Missing 'transcript_text' field")  # Expected: 400 error with missing field message
test_api(empty_transcript_data, "Empty 'transcript_text'")        # Expected: 400 error with non-empty transcript message
test_api(too_long_transcript_data, "Transcript exceeding 20,000 tokens")  # Expected: 400 error with token limit message
# Out:
# Testing: Valid input
# Status Code: 200
# ...
